# %%
#!pip install psycopg2

# %%
##import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sqlalchemy import create_engine
import psycopg2

from config import user, password

# %%
engine = create_engine(f'postgresql://{user}:{password}@localhost:5432/employees_db')
connection = engine.connect()

# %% [markdown]
# # Average Salary by Title

# %%
#collect titles df

titles_df = pd.read_sql('SELECT * FROM titles', connection)
titles_df
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
#collect salaries df

salaries_df = pd.read_sql('SELECT * FROM salaries', connection)
salaries_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
### link the salaries df to the title df 

employees_df= pd.read_sql('SELECT * FROM employees', connection)
employees_df

merge_df = employees_df.merge(salaries_df, on = "emp_no", how = "outer")
merge_df = merge_df.merge(titles_df, left_on = "emp_title", right_on= 'title_id', how = "outer")
merge_df
# Out:
#         emp_no emp_title  birth_date  first_name   last_name sex   hire_date  \
# 0       473302     s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1       421786     s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2       273487     s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3       246449     s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4        48085     s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
# ...        ...       ...         ...         ...         ...  ..         ...
# 300019  111400     m0001  1959-11-09        Arie     Staelin   M  1985-01-01
# 300020  111133     m0001  1955-03-16       Hauke       Zhang   M  1986-12-30
# 300021  110085     m0001  1959-10-28        Ebru       Alpin   M  1985-01-01
# 300022  110386     m0001  1953-10-04        Shem      Kieras   M  1988-10-14
# 300023  111784     m0001  1956-06-14       Marjo  Giarratana   F  1988-02-12
#
#         salary title_id    title
# ...

# %%
### generate average salary by title data

avg_salary= merge_df.groupby(by = 'title', dropna = False).mean()
avg_salary
# Out:
#                            emp_no        salary
# title
# Assistant Engineer  252992.595373  48564.434447
# Engineer            253654.345919  48535.336511
# Manager             110780.833333  51531.041667
# Senior Engineer     253038.749885  48506.799871
# Senior Staff        254481.798969  58550.172704
# Staff               253408.503604  58465.382850
# Technique Leader    251811.432730  48582.896092

# %%
#### Bar Chart

fig, ax1 = plt.subplots(figsize=(9, 7))

x_axis = np.arange(len(titles_df))
x_labels = list(avg_salary.index.values)

plt.bar(x_axis, avg_salary['salary'], align= 'center')
plt.xticks(x_axis, x_labels, rotation =90)

plt.title("Average Salary by Title")

plt.ylabel("Average Salary")
plt.xlabeL("Employee Title")

plt.savefig('output/BarPlot_avgsal_title.png')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9a7fd2ccafd5> in <module>
#      12
#      13 plt.ylabel("Average Salary")
# ---> 14 plt.xlabeL("Employee Title")
#      15
#      16 plt.savefig('output/BarPlot_avgsal_title.png')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabeL'
